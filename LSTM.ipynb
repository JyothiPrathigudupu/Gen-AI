# %% [markdown]
# # Importing Libraries

# %%
import pandas
import matplotlib.pyplot as plt
dataset = pandas.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()

# %% [markdown]
# # Loading Dataset

# %%
import pandas
import matplotlib.pyplot as plt
dataset = pandas.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()

# %% [markdown]
# # LSTM for international airline passengers problem with regression framing

# %%
# LSTM for international airline passengers problem with regression framing
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # convert an array of values into a dataset matrix

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# # fix random seed for reproducibility

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
dataframe.head()
# Out:
#    total_passengers
# 0               112
# 1               118
# 2               132
# 3               129
# 4               121

# %% [markdown]
# # normalize the dataset

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# # split into train and test sets

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# # reshape into X=t and Y=t+1

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %% [markdown]
# # reshape input to be [samples, time steps, features]

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # create and fit the LSTM network

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# C:\Users\nr802\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 94/94 - 3s - 34ms/step - loss: 0.0366
# Epoch 2/100
# 94/94 - 0s - 2ms/step - loss: 0.0177
# Epoch 3/100
# 94/94 - 0s - 2ms/step - loss: 0.0133
# Epoch 4/100
# 94/94 - 0s - 2ms/step - loss: 0.0121
# Epoch 5/100
# 94/94 - 0s - 2ms/step - loss: 0.0111
# Epoch 6/100
# 94/94 - 0s - 2ms/step - loss: 0.0102
# Epoch 7/100
# 94/94 - 0s - 2ms/step - loss: 0.0093
# Epoch 8/100
# 94/94 - 0s - 2ms/step - loss: 0.0084
# Epoch 9/100
# 94/94 - 0s - 2ms/step - loss: 0.0075
# Epoch 10/100
# 94/94 - 0s - 2ms/step - loss: 0.0066
# Epoch 11/100
# 94/94 - 0s - 4ms/step - loss: 0.0058
# Epoch 12/100
# 94/94 - 0s - 2ms/step - loss: 0.0051
# Epoch 13/100
# 94/94 - 0s - 2ms/step - loss: 0.0044
# Epoch 14/100
# 94/94 - 0s - 2ms/step - loss: 0.0039
# Epoch 15/100
# 94/94 - 0s - 2ms/step - loss: 0.0034
# Epoch 16/100
# 94/94 - 0s - 2ms/step - loss: 0.0030
# Epoch 17/100
# 94/94 - 0s - 2ms/step - loss: 0.0027
# Epoch 18/100
# 94/94 - 0s - 3ms/step - loss: 0.0025
# Epoch 19/100
# 94/94 - 0s - 3ms/step - loss: 0.0023
# Epoch 20/100
# 94/94 - 0s - 3ms/step - loss: 0.0022
# Epoch 21/100
# 94/94 - 0s - 2ms/step - loss: 0.0021
# Epoch 22/100
# 94/94 - 0s - 2ms/step - loss: 0.0021
# Epoch 23/100
# 94/94 - 0s - 2ms/step - loss: 0.0021
# Epoch 24/100
# 94/94 - 0s - 4ms/step - loss: 0.0020
# Epoch 25/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 26/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 27/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 28/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 29/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 30/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 31/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 32/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 33/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 34/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 35/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 36/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 37/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 38/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 39/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 40/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 41/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 42/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 43/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 44/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 45/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 46/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 47/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 48/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 49/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 50/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 51/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 52/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 53/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 54/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 55/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 56/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 57/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 58/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 59/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 60/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 61/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 62/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 63/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 64/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 65/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 66/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 67/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 68/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 69/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 70/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 71/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 72/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 73/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 74/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 75/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 76/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 77/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 78/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 79/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 80/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 81/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 82/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 83/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 84/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 85/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 86/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 87/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 88/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 89/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 90/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 91/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 92/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 93/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 94/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 95/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 96/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 97/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 98/100
# 94/94 - 0s - 3ms/step - loss: 0.0020
# Epoch 99/100
# 94/94 - 0s - 2ms/step - loss: 0.0020
# Epoch 100/100
# 94/94 - 0s - 2ms/step - loss: 0.0020

# %% [markdown]
# # make predictions

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# # invert predictions

# %%
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# # calculate root mean squared error

# %%
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 22.74 RMSE
# Test Score: 50.23 RMSE

# %% [markdown]
# # shift train predictions for plotting

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %% [markdown]
# # shift test predictions for plotting

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %% [markdown]
# # plot baseline and predictions

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\nr802\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\nr802\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nr802\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\nr802\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\nr802\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\nr802\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nr802\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nr802\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nr802\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nr802\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nr802\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nr802\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nr802\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nr802\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\nr802\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nr802\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nr802\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)

# %%
# LSTM for international airline passengers problem with memory
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 42
#      40 batch_size = 1
#      41 model = Sequential()
# ---> 42 model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
#      43 model.add(Dense(1))
#      44 model.compile(loss='mean_squared_error', optimizer='adam')
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:486, in LSTM.__init__(self, units, activation, recurrent_activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, unit_forget_bias, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, seed, return_sequences, return_state, go_backwards, stateful, unroll, use_cudnn, **kwargs)
#     435 def __init__(
#     436     self,
#     437     units,
#    (...)
#     461     **kwargs,
#     462 ):
#     463     cell = LSTMCell(
#     464         units,
#     465         activation=activation,
#    (...)
#     484         implementation=kwargs.pop("implementation", 2),
#     485     )
# --> 486     super().__init__(
#     487         cell,
#     488         return_sequences=return_sequences,
#     489         return_state=return_state,
#     490         go_backwards=go_backwards,
#     491         stateful=stateful,
#     492         unroll=unroll,
#     493         activity_regularizer=activity_regularizer,
#     494         **kwargs,
#     495     )
#     496     self.input_spec = InputSpec(ndim=3)
#     497     if use_cudnn not in ("auto", True, False):
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204, in RNN.__init__(self, cell, return_sequences, return_state, go_backwards, stateful, unroll, zero_output_for_mask, **kwargs)
#     197 if "state_size" not in dir(cell):
#     198     raise ValueError(
#     199         "The RNN cell should have a `state_size` attribute "
#     200         "(single integer or list of integers, "
#     201         "one integer per RNN state). "
#     202         f"Received: cell={cell}"
#     203     )
# --> 204 super().__init__(**kwargs)
#     206 # If True, the output for masked timestep will be zeros, whereas in the
#     207 # False case, output from previous timestep is returned for masked
#     208 # timestep.
#     209 self.zero_output_for_mask = zero_output_for_mask
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\layer.py:285, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     283     self._input_shape_arg = input_shape_arg
#     284 if kwargs:
# --> 285     raise ValueError(
#     286         "Unrecognized keyword arguments "
#     287         f"passed to {self.__class__.__name__}: {kwargs}"
#     288     )
#     290 self._path = None  # Will be determined in `build_wrapper`
#     291 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to LSTM: {'batch_input_shape': (1, 3, 1)}

# %%
# Stacked LSTM for international airline passengers problem with memory
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 42
#      40 batch_size = 1
#      41 model = Sequential()
# ---> 42 model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
#      43 model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
#      44 model.add(Dense(1))
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:486, in LSTM.__init__(self, units, activation, recurrent_activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, unit_forget_bias, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, seed, return_sequences, return_state, go_backwards, stateful, unroll, use_cudnn, **kwargs)
#     435 def __init__(
#     436     self,
#     437     units,
#    (...)
#     461     **kwargs,
#     462 ):
#     463     cell = LSTMCell(
#     464         units,
#     465         activation=activation,
#    (...)
#     484         implementation=kwargs.pop("implementation", 2),
#     485     )
# --> 486     super().__init__(
#     487         cell,
#     488         return_sequences=return_sequences,
#     489         return_state=return_state,
#     490         go_backwards=go_backwards,
#     491         stateful=stateful,
#     492         unroll=unroll,
#     493         activity_regularizer=activity_regularizer,
#     494         **kwargs,
#     495     )
#     496     self.input_spec = InputSpec(ndim=3)
#     497     if use_cudnn not in ("auto", True, False):
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204, in RNN.__init__(self, cell, return_sequences, return_state, go_backwards, stateful, unroll, zero_output_for_mask, **kwargs)
#     197 if "state_size" not in dir(cell):
#     198     raise ValueError(
#     199         "The RNN cell should have a `state_size` attribute "
#     200         "(single integer or list of integers, "
#     201         "one integer per RNN state). "
#     202         f"Received: cell={cell}"
#     203     )
# --> 204 super().__init__(**kwargs)
#     206 # If True, the output for masked timestep will be zeros, whereas in the
#     207 # False case, output from previous timestep is returned for masked
#     208 # timestep.
#     209 self.zero_output_for_mask = zero_output_for_mask
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\layer.py:285, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     283     self._input_shape_arg = input_shape_arg
#     284 if kwargs:
# --> 285     raise ValueError(
#     286         "Unrecognized keyword arguments "
#     287         f"passed to {self.__class__.__name__}: {kwargs}"
#     288     )
#     290 self._path = None  # Will be determined in `build_wrapper`
#     291 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to LSTM: {'batch_input_shape': (1, 3, 1)}
